# %%
import pandas as pd
import numpy as np
import requests
import zipfile
import io

# %%
# Посилання на файл Stack Overflow
url = "https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip"
print("-" * 105)
# Завантаження архіву в пам'ять та розпакування файлів
try:
    print("Починаємо завантаження... це може зайняти хвилину.")
    
    res = requests.get(url, timeout=60, stream=True) # stream=True допомагає при завантаженні великих файлів

    if res.status_code == 200:
        with zipfile.ZipFile(io.BytesIO(res.content)) as z:
            z.extractall("overflow_2025")
            print("Успіх! Файли розпаковано в 'overflow_2025'")
            print("Вміст папки:", z.namelist())
    else:
        print(f"Помилка: Сервер повернув статус {res.status_code}")
        
except requests.exceptions.RequestException as e:
    print(f"Виникла помилка при з'єднанні: {e}")
print("-" * 105)
# Out:
# ---------------------------------------------------------------------------------------------------------
# Починаємо завантаження... це може зайняти хвилину.
# Успіх! Файли розпаковано в 'overflow_2025'
# Вміст папки: ['2025_Developer_Survey_Tool.pdf', 'survey_results_public.csv', 'survey_results_schema.csv']
# ---------------------------------------------------------------------------------------------------------

# %%
# Завантаження *.csv файлів з вимкненням попередження про типи (low_memory=False) 
#                           та використання стандартного декодування (encoding='utf-8')
print("-" * 35)
# Завантаження файлу 'survey_results_public.csv'
survey_results_public = pd.read_csv("overflow_2025/survey_results_public.csv", low_memory=False, encoding='utf-8')
print("Основні дані завантажено успішно!")

# Завантаження файлу 'survey_results_schema.csv'
print(" ")
survey_results_schema = pd.read_csv("overflow_2025/survey_results_schema.csv", low_memory=False, encoding='utf-8')
print("Опис структури завантажено успішно!")
print("-" * 35)
# Out:
# -----------------------------------
# Основні дані завантажено успішно!
#
# Опис структури завантажено успішно!
# -----------------------------------

# %%
# Налаштування відображення всіх колонок
pd.set_option('display.max_columns', None)

# %%
# Опитування респондентів
survey_results_public
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
# Питання з опитуваннями
survey_results_schema
# Out:
#         qid            qname  \
# 0     QID18    TechEndorse_1
# 1     QID18    TechEndorse_2
# 2     QID18    TechEndorse_3
# 3     QID18    TechEndorse_4
# 4     QID18    TechEndorse_5
# ..      ...              ...
# 134  QID103  AIAgentObsWrite
# 135   QID92  AIAgentExternal
# 136  QID104  AIAgentExtWrite
# 137  QID100          AIHuman
# 138   QID93           AIOpen
#
#                                               question type  \
# 0    What attracts you to a technology or causes yo...   RO
# 1    What attracts you to a technology or causes yo...   RO
# 2    What attracts you to a technology or causes yo...   RO
# 3    What attracts you to a technology or causes yo...   RO
# 4    What attracts you to a technology or causes yo...   RO
# ..                                                 ...  ...
# 134  Was the tool or tools for AI agent observabili...   TE
# 135  You indicated you use or develop AI agents as ...   MC
# 136  Was the out-of-the-box agents, copilots or ass...   TE
# ...

# %% [markdown]
# Завдання 1. Підрахунок загальної кількості респондентів

# %%
# Підраховуємо загальну кількость респондентів
total_resp = len(survey_results_public)
# або 
# total_resp_1 = survey_results_public['ResponseId'].nunique() # для перевірки на дублікати(можливо був збій)
print("-" * 66)
print(f"Загальна кількість респондентів що взяли учать в опитуванні: {total_resp}")
# print(f"Загальна кількість респондентів що взяли учать в опитуванні: {total_resp_1}")
print("-" * 66)
# Out:
# ------------------------------------------------------------------
# Загальна кількість респондентів що взяли учать в опитуванні: 49191
# ------------------------------------------------------------------

# %% [markdown]
# Завдання 2. Аналіз повноти відповідей респондентів

# %%
# Отримуємо список питань як множину
questions_set = set(survey_results_schema['qname'].unique())

# Отримуємо список наявних колонок у даних як множину
columns_set = set(survey_results_public.columns)

# Використовуємо інтерсекцію (перетин) множин для отримання списку колонок
# це гарантує, що ми аналізуємо лише ті поля, які є і в схемі, і в даних
relevant_columns = list(questions_set.intersection(columns_set))

# Використовуємо метод .dropna(), щоб залишити тільки рядки без жодного NaN 
# у вибраних колонках, і рахуємо їх кількість через len()
all_answered = survey_results_public.dropna(subset=relevant_columns)
final_result = len(all_answered)

print("-" * 57)
print(f"Аналізувалося колонок: {len(relevant_columns)}")
print(f"Кількість респондентів, які відповіли на всі запитання: {final_result}")
print("-" * 57)
# Out:
# ---------------------------------------------------------
# Аналізувалося колонок: 126
# Кількість респондентів, які відповіли на всі запитання: 0
# ---------------------------------------------------------

# %% [markdown]
# Завдання 3. Статистичний аналіз досвіду респондентів

# %%
# Знаходимо Середнє значення респондентів (mean)
workexp_mean = survey_results_public['WorkExp'].mean().round(1)
# Знаходимо Медіану респондентів (median)
workexp_median = survey_results_public['WorkExp'].median()
# Знаходимо Моду респондентів (mode) 
workexp_mode = survey_results_public['WorkExp'].mode()


print("-" * 39)
print(f"Міри центральної тенденції для WorkExp:")
print("-" * 39)
print(f"Середнє значення стажу роботи :  {workexp_mean}")
print(f"Медіана стажу роботи :           {workexp_median}")
print(f"Мода стажу роботи :              {workexp_mode[0]}")
print("-" * 39)
# Out:
# ---------------------------------------
# Міри центральної тенденції для WorkExp:
# ---------------------------------------
# Середнє значення стажу роботи :  13.4
# Медіана стажу роботи :           10.0
# Мода стажу роботи :              10.0
# ---------------------------------------

# %% [markdown]
# Завдання 4. Аналіз віддаленої роботи

# %%
# Знаходимо кількість респондентів, які працюють віддалено
resp_coun_rem = len(survey_results_public[survey_results_public['RemoteWork'] == 'Remote'])

print("-" * 53)
print(f"Кількість респондентів, які працюють віддалено: {resp_coun_rem}")
print("-" * 53)
# Out:
# -----------------------------------------------------
# Кількість респондентів, які працюють віддалено: 10931
# -----------------------------------------------------

# %% [markdown]
# Завдання 5. Визначення популярності Python

# %%
# Колонка з мовами програмування
column_langs = 'LanguageHaveWorkedWith'

# Фільтруємо респондентів, які програмують на Python na=False допомагає ігнорувати пропуски (NaN) у даних
users_python = survey_results_public[survey_results_public[column_langs].str.contains('Python', na=False)]

# Підраховуємо кількість користувачів Python та загальну кількість респондентів
python_count = len(users_python)
total_respondents = len(survey_results_public)

# Розраховуємо відсоток
python_percent = (python_count / total_respondents) * 100

print("-" * 56)
print(f"Відсоток респондентів, які програмують на Python: {python_percent:.1f} %")
print("-" * 56)
# Out:
# --------------------------------------------------------
# Відсоток респондентів, які програмують на Python: 37.5 %
# --------------------------------------------------------

# %% [markdown]
# Завдання 6. Аналіз шляхів навчання програмуванню

# %%
# Колонка зі способами навчання
learn_col = 'LearnCode'

# Фільтруємо респондентів, які навчалися програмувати за допомогою онлайн курсів
online_learners = survey_results_public[survey_results_public[learn_col].str.contains('Online Courses or Certification', na=False)]

# Підраховуємо кількість
count_online_learners = len(online_learners)

print("-" * 63)
print(f"Кількість респондентів, які навчалися через онлайн-курси: {count_online_learners}")
print("-" * 63)
# Out:
# ---------------------------------------------------------------
# Кількість респондентів, які навчалися через онлайн-курси: 10973
# ---------------------------------------------------------------

# %% [markdown]
# Завдання 7. Географічний аналіз компенсації Python-розробників

# %%
# Знаходимо середню (mean) та медіанну (median) сум сумакомпенсації,
# використовуючи таблицю з завдання 5 "country_python"
country_python = (users_python.groupby('Country')['ConvertedCompYearly']
    .agg(responses = 'count', mean_comp = 'mean', median_comp = 'median').round(2))
# Видаляємо країни де взагалі немає даних про компенсацію.
country_python_clean = country_python.dropna().reset_index()

print("-" * 30)
print(f"Було рядків: {len(country_python)}")
print(f"Видалено рядків: {len(country_python) - len(country_python_clean)}")
print(f"Кількість очищених рядків: {len(country_python_clean)}")
print("-" * 30)

country_python_clean
# Out:
# ------------------------------
# Було рядків: 167
# Видалено рядків: 14
# Кількість очищених рядків: 153
# ------------------------------
#                                   Country  responses  mean_comp  median_comp
# 0                             Afghanistan          3   22328.67       1000.0
# 1                                 Albania          5   47217.60      50000.0
# 2                                 Algeria          7   20187.29       7088.0
# 3                                 Andorra          2  226103.50     226103.5
# 4                     Antigua and Barbuda          1       1.00          1.0
# ..                                    ...        ...        ...          ...
# 148  Venezuela, Bolivarian Republic of...         17    9908.65       3000.0
# 149                              Viet Nam         30  218837.17       8254.0
# 150                                 Yemen          4   32929.50      23672.0
# ...

# %% [markdown]
# Завдання 8. Аналіз освіти найбільш оплачуваних спеціалістів

# %%
# Варіант 1 з урахуванням усіх аномалій
# Відсортуємо респондентів за рівнем компенсації у спадному порядку
sort_top_5_resp = survey_results_public.sort_values(by='ConvertedCompYearly', ascending=False).head(5).reset_index().copy()

# Виберемо топ-5 та покажемо їх рівні освіти
top_5_resp = sort_top_5_resp[['ResponseId', 'EdLevel', 'ConvertedCompYearly']]

print("-" * 45)
print(" ТОП-5 за сирими даними (включаючи аномалії):")
print("-" * 45)
top_5_resp
# Out:
# ---------------------------------------------
#  ТОП-5 за сирими даними (включаючи аномалії):
# ---------------------------------------------
#    ResponseId                                          EdLevel  \
# 0       34268              Associate degree (A.A., A.S., etc.)
# 1       28701  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2       43144              Associate degree (A.A., A.S., etc.)
# 3       35354     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       45972  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#    ConvertedCompYearly
# 0           50000000.0
# 1           33552715.0
# 2           18387548.0
# 3           15430267.0
# 4           13921760.0

# %%
# Варіант 2 з відсіканням аномалій понад $ 500 000)
# Фільтруємо нереальні зарплати та пропуски
real_resp = survey_results_public[survey_results_public['ConvertedCompYearly'] < 500000]

# Сортуємо та беремо топ-5
sort_top_5_real = real_resp.sort_values(by='ConvertedCompYearly', ascending=False).head(5).reset_index().copy()

# Вибираємо потрібні колонки
top_5_realistic_resp = sort_top_5_real[['ResponseId', 'EdLevel', 'ConvertedCompYearly']]

print("-" * 58)
print(" ТОП-5 після очищення від аномалій (зарплати < $ 500 000):")
print("-" * 58)
top_5_realistic_resp
# Out:
# ----------------------------------------------------------
#  ТОП-5 після очищення від аномалій (зарплати < $ 500 000):
# ----------------------------------------------------------
#    ResponseId                                            EdLevel  \
# 0       12944    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1        1788       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2       22800  Some college/university study without earning ...
# 3       11417                Associate degree (A.A., A.S., etc.)
# 4       20933       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#    ConvertedCompYearly
# 0             499750.0
# 1             480000.0
# 2             480000.0
# 3             480000.0
# 4             480000.0

# %% [markdown]
# *Завдання 9. Аналіз популярності Python по віковим категоріям
# *(виконання необов'язкове, за бажанням)

# %%
# Групуємо Python-розробників за віком та рахуємо їх кількість
# використовуючи таблицю з завдання 5 "country_python"
age_category = users_python.groupby('Age')['Age'].agg(age_count='count').reset_index()

# 2. Рахуємо відсоток від ЗАГАЛЬНОЇ кількості респондентів
total_survey_count = len(survey_results_public)
age_category['age_count_%'] = (age_category['age_count'] / total_survey_count * 100).round(2)

# 3. Сортуємо, щоб побачити наймасовішу категорію
age_category = age_category.sort_values(by='Age', ascending=True)

print("-" * 44)
print(f"Популярність Python по віковим категоріям:")
print("-" * 44)
print(age_category)
print("-" * 44)
# Out:
# --------------------------------------------
# Популярність Python по віковим категоріям:
# --------------------------------------------
#                  Age  age_count  age_count_%
# 0    18-24 years old       3684         7.49
# 1    25-34 years old       6102        12.40
# 2    35-44 years old       4862         9.88
# 3    45-54 years old       2424         4.93
# 4    55-64 years old        978         1.99
# 5  65 years or older        298         0.61
# 6  Prefer not to say        118         0.24
# --------------------------------------------

# %% [markdown]
# *Завдання 10. Аналіз індустрій серед високооплачуваних віддалених працівників *(виконання необов'язкове, за бажанням)

# %%
# знаходимо персентиль 75
percent_75 = survey_results_public['ConvertedCompYearly'].quantile(0.75)

# фільтруемо респондентів які працюють віддалено та знаходяться у 75 перцентилі за компенсацією
percent_75_clean = survey_results_public[(survey_results_public['RemoteWork'] == 'Remote') & 
    (survey_results_public['ConvertedCompYearly'] >= percent_75)]

# Визначаємо найрозповсюдженіші індустрії
industry = (percent_75_clean['Industry'].value_counts())

print("-" * 76)
print(f"Значення 75 перцентиля: {percent_75}") 

print(f"Найрозповсюдженіші індустрії серед високооплачуваних віддалених працівників:")
print("-" * 76)
print(industry)
# Out:
# ----------------------------------------------------------------------------
# Значення 75 перцентиля: 120596.0
# Найрозповсюдженіші індустрії серед високооплачуваних віддалених працівників:
# ----------------------------------------------------------------------------
# Industry
# Software Development                          1186
# Fintech                                        190
# Healthcare                                     188
# Other:                                         176
# Internet, Telecomm or Information Services     138
# Banking/Financial Services                      88
# Government                                      78
# Media & Advertising Services                    75
# Retail and Consumer Services                    65
# Transportation, or Supply Chain                 63
# Computer Systems Design and Services            59
# Insurance                                       46
# Energy                                          45
# ...
